# %%
import os 
import folium
from folium import plugins
#import rioxarray as rxr
#import earthpy as et
#import earthpy.spatial as es
import osmnx as ox

import pandas as pd
import geopandas
import matplotlib.pyplot as plt

# %% [markdown]
# https://towardsdatascience.com/retrieving-openstreetmap-data-in-python-1777a4be45bb
#
# https://www.analyticsvidhya.com/blog/2020/06/guide-geospatial-analysis-folium-python/

# %% [markdown]
# ### Test streamlit widdgets

# %% [markdown]
# ## Fetch data

# %%
df_reims = ox.geocode_to_gdf('reims')
reims = 'Reims, France'

graph = ox.graph_from_place(reims, network_type='drive')

# %%
nodes, streets = ox.graph_to_gdfs(graph)
streets.head()
# Out:
#                                                      osmid  oneway  \
# u        v          key
# 23218064 1095837840 0                              4748014    True
# 23218073 23218064   0    [779386768, 683144866, 683144867]    True
# 23218075 36237896   0                              5193465    True
#          270759660  0                            111245364    True
# 23218084 23218102   0    [683144858, 683144859, 683144860]    True
#
#                                highway reversed    length lanes    ref  \
# u        v          key
# 23218064 1095837840 0    motorway_link    False   155.362   NaN    NaN
# 23218073 23218064   0         motorway    False  1393.540     3  A 344
# 23218075 36237896   0    motorway_link    False   476.810   NaN    NaN
#          270759660  0         motorway    False   486.002     3  A 344
# 23218084 23218102   0         motorway    False   426.767     3  A 344
#
#                                          name maxspeed bridge  \
# u        v          key
# 23218064 1095837840 0                     NaN      NaN    NaN
# 23218073 23218064   0    Voie Jean Taittinger       90    yes
# 23218075 36237896   0                     NaN      NaN    NaN
#          270759660  0    Voie Jean Taittinger       90    NaN
# 23218084 23218102   0    Voie Jean Taittinger       90    NaN
#
#                                                                   geometry  \
# u        v          key
# 23218064 1095837840 0      LINESTRING (4.06007 49.22556, 4.06196 49.22491)
# 23218073 23218064   0    LINESTRING (4.04335 49.23148, 4.04394 49.23106...
# 23218075 36237896   0    LINESTRING (4.04478 49.23071, 4.04425 49.23116...
#          270759660  0    LINESTRING (4.04478 49.23071, 4.04406 49.23117...
# 23218084 23218102   0    LINESTRING (4.02644 49.24753, 4.02470 49.24877...
#
#                         junction tunnel access width
# u        v          key
# 23218064 1095837840 0        NaN    NaN    NaN   NaN
# 23218073 23218064   0        NaN    NaN    NaN   NaN
# 23218075 36237896   0        NaN    NaN    NaN   NaN
#          270759660  0        NaN    NaN    NaN   NaN
# 23218084 23218102   0        NaN    NaN    NaN   NaN

# %% [markdown]
# ## Search for streets with scientific names

# %%
scientifics = streets[streets['name']=='Voie Jean Taittinger']

# %%
G = ox.graph_from_address('3 rue Adrien Sénéchal, 51100, REIMS')
#ox.plot_graph(G)
node_id = list(G.nodes)[0]
print(G.nodes[node_id]['x'],G.nodes[node_id]['y']) #lon, #lat

#nodesGB_quartier, GB_quartier = ox.graph_to_gdfs(G)
#nodesGB_quartier
#GB_quartier

GB_latlong = [49.22311782149911, 4.0165995097933]
# Out:
# 4.0212378 49.2195506

# %%
G2 = ox.graph_from_point(GB_latlong, dist=750, dist_type='bbox', network_type='drive')
nodesGB2_quartier, GB2_quartier = ox.graph_to_gdfs(G2)
# Out:
#                                             osmid lanes  \
# u           v          key
# 36237904    36237992   0                  5193468     3
# 36237988    36237990   0               1026694428     3
# 36237989    36237904   0                  5193468     3
# 36237990    348153201  0                 27422377   NaN
#             280025004  0               1026694427     3
# ...                                           ...   ...
# 9088682829  270759554  0                982887322   NaN
# 9088682830  9088682829 0                982887321   NaN
#             6967193286 0    [31292696, 777819823]   NaN
# 10222392060 8500398277 0               1117677811   NaN
#             348153196  0                854636462   NaN
#
#                                                                name  \
# u           v          key
# 36237904    36237992   0    Place des Combattants d'Afrique du Nord
# 36237988    36237990   0    Place des Combattants d'Afrique du Nord
# 36237989    36237904   0    Place des Combattants d'Afrique du Nord
# 36237990    348153201  0                    Avenue du Maréchal Juin
#             280025004  0    Place des Combattants d'Afrique du Nord
# ...                                                             ...
# 9088682829  270759554  0                      Rue du Général Koenig
# 9088682830  9088682829 0                                        NaN
#             6967193286 0                      Rue du Général Koenig
# 10222392060 8500398277 0                                        NaN
#             348153196  0                    Avenue du Maréchal Juin
#
#                                 highway maxspeed    junction  oneway  \
# u           v          key
# 36237904    36237992   0        primary       30  roundabout    True
# 36237988    36237990   0        primary       30  roundabout    True
# 36237989    36237904   0        primary       30  roundabout    True
# 36237990    348153201  0      secondary       50         NaN    True
#             280025004  0        primary       30  roundabout    True
# ...                                 ...      ...         ...     ...
# 9088682829  270759554  0    residential       50         NaN    True
# 9088682830  9088682829 0    residential      NaN         NaN    True
#             6967193286 0    residential       50         NaN    True
# 10222392060 8500398277 0    residential      NaN         NaN   False
#             348153196  0      secondary       50         NaN    True
#
#                             reversed   length  \
# u           v          key
# 36237904    36237992   0       False   46.335
# 36237988    36237990   0       False   27.989
# 36237989    36237904   0       False   41.237
# 36237990    348153201  0       False   95.472
#             280025004  0       False   37.826
# ...                              ...      ...
# 9088682829  270759554  0       False   57.726
# 9088682830  9088682829 0       False    8.225
#             6967193286 0       False  106.838
# 10222392060 8500398277 0        True   10.407
#             348153196  0       False   23.142
#
#                                                                      geometry  \
# u           v          key
# 36237904    36237992   0    LINESTRING (4.02124 49.21955, 4.02145 49.21956...
# 36237988    36237990   0    LINESTRING (4.02133 49.22040, 4.02114 49.22039...
# 36237989    36237904   0    LINESTRING (4.02077 49.21974, 4.02089 49.21965...
# 36237990    348153201  0    LINESTRING (4.02097 49.22034, 4.02079 49.22037...
#             280025004  0    LINESTRING (4.02097 49.22034, 4.02083 49.22026...
# ...                                                                       ...
# 9088682829  270759554  0    LINESTRING (4.02416 49.22663, 4.02424 49.22665...
# 9088682830  9088682829 0      LINESTRING (4.02420 49.22669, 4.02416 49.22663)
#             6967193286 0    LINESTRING (4.02420 49.22669, 4.02400 49.22665...
# 10222392060 8500398277 0      LINESTRING (4.01804 49.22400, 4.01790 49.22400)
#             348153196  0    LINESTRING (4.01804 49.22400, 4.01804 49.22401...
#
#                             ref
# u           v          key
# 36237904    36237992   0    NaN
# 36237988    36237990   0    NaN
# 36237989    36237904   0    NaN
# 36237990    348153201  0    NaN
#             280025004  0    NaN
# ...                         ...
# 9088682829  270759554  0    NaN
# 9088682830  9088682829 0    NaN
#             6967193286 0    NaN
# 10222392060 8500398277 0    NaN
#             348153196  0    NaN
#
# [329 rows x 11 columns]

# %%
# scikit-learn must be installed to search for unprojected graph
#G3 = ox.graph_from_point(GB_latlong, dist=500, dist_type='network')

# %%
ox.plot_graph(G2)
# Out:
# (<Figure size 800x800 with 1 Axes>, <AxesSubplot: >)

# %% [markdown]
# ## Add points of interest

# %%
nodesGB_quartier, GB_quartier = ox.graph_to_gdfs(G)
GB_quartier['name']
nodesGB = nodesGB_quartier.iloc[0:1]
nodesGB
# Out:
#                   y         x  street_count highway                  geometry
# osmid
# 36237904  49.219551  4.021238             3     NaN  POINT (4.02124 49.21955)

# %%
GB2_quartier
# Out:
#                                             osmid lanes  \
# u           v          key
# 36237904    36237992   0                  5193468     3
# 36237988    36237990   0               1026694428     3
# 36237989    36237904   0                  5193468     3
# 36237990    348153201  0                 27422377   NaN
#             280025004  0               1026694427     3
# ...                                           ...   ...
# 9088682829  270759554  0                982887322   NaN
# 9088682830  9088682829 0                982887321   NaN
#             6967193286 0    [31292696, 777819823]   NaN
# 10222392060 8500398277 0               1117677811   NaN
#             348153196  0                854636462   NaN
#
#                                                                name  \
# u           v          key
# 36237904    36237992   0    Place des Combattants d'Afrique du Nord
# 36237988    36237990   0    Place des Combattants d'Afrique du Nord
# 36237989    36237904   0    Place des Combattants d'Afrique du Nord
# 36237990    348153201  0                    Avenue du Maréchal Juin
#             280025004  0    Place des Combattants d'Afrique du Nord
# ...                                                             ...
# 9088682829  270759554  0                      Rue du Général Koenig
# 9088682830  9088682829 0                                        NaN
#             6967193286 0                      Rue du Général Koenig
# 10222392060 8500398277 0                                        NaN
#             348153196  0                    Avenue du Maréchal Juin
#
#                                 highway maxspeed    junction  oneway  \
# u           v          key
# 36237904    36237992   0        primary       30  roundabout    True
# 36237988    36237990   0        primary       30  roundabout    True
# 36237989    36237904   0        primary       30  roundabout    True
# 36237990    348153201  0      secondary       50         NaN    True
#             280025004  0        primary       30  roundabout    True
# ...                                 ...      ...         ...     ...
# 9088682829  270759554  0    residential       50         NaN    True
# 9088682830  9088682829 0    residential      NaN         NaN    True
#             6967193286 0    residential       50         NaN    True
# 10222392060 8500398277 0    residential      NaN         NaN   False
#             348153196  0      secondary       50         NaN    True
#
#                             reversed   length  \
# u           v          key
# 36237904    36237992   0       False   46.335
# 36237988    36237990   0       False   27.989
# 36237989    36237904   0       False   41.237
# 36237990    348153201  0       False   95.472
#             280025004  0       False   37.826
# ...                              ...      ...
# 9088682829  270759554  0       False   57.726
# 9088682830  9088682829 0       False    8.225
#             6967193286 0       False  106.838
# 10222392060 8500398277 0        True   10.407
#             348153196  0       False   23.142
#
#                                                                      geometry  \
# u           v          key
# 36237904    36237992   0    LINESTRING (4.02124 49.21955, 4.02145 49.21956...
# 36237988    36237990   0    LINESTRING (4.02133 49.22040, 4.02114 49.22039...
# 36237989    36237904   0    LINESTRING (4.02077 49.21974, 4.02089 49.21965...
# 36237990    348153201  0    LINESTRING (4.02097 49.22034, 4.02079 49.22037...
#             280025004  0    LINESTRING (4.02097 49.22034, 4.02083 49.22026...
# ...                                                                       ...
# 9088682829  270759554  0    LINESTRING (4.02416 49.22663, 4.02424 49.22665...
# 9088682830  9088682829 0      LINESTRING (4.02420 49.22669, 4.02416 49.22663)
#             6967193286 0    LINESTRING (4.02420 49.22669, 4.02400 49.22665...
# 10222392060 8500398277 0      LINESTRING (4.01804 49.22400, 4.01790 49.22400)
#             348153196  0    LINESTRING (4.01804 49.22400, 4.01804 49.22401...
#
#                             ref
# u           v          key
# 36237904    36237992   0    NaN
# 36237988    36237990   0    NaN
# 36237989    36237904   0    NaN
# 36237990    348153201  0    NaN
#             280025004  0    NaN
# ...                         ...
# 9088682829  270759554  0    NaN
# 9088682830  9088682829 0    NaN
#             6967193286 0    NaN
# 10222392060 8500398277 0    NaN
#             348153196  0    NaN
#
# [329 rows x 11 columns]

# %%
fig, ax = plt.subplots(figsize=(24, 18))
GB_quartier2.plot(ax=ax, legend=True)
ax.scatter(GB_latlong[0],GB_latlong[1],color='green')
plt.title("Reims")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 fig, ax = plt.subplots(figsize=(24, 18))
# ----> 2 GB_quartier2.plot(ax=ax, legend=True)
#       3 ax.scatter(GB_latlong[0],GB_latlong[1],color='green')
#       4 plt.title("Reims")
#
# NameError: name 'GB_quartier2' is not defined

# %% [markdown]
# ## Plot using folium explore (interactive)

# %%
m = streets.explore()
test.explore(m=m, color='red',
             tooltip="name", # show "name" column in the tooltip)
            )
GB_quartier.explore(m=m, color='green',
             tooltip="name", # show "name" column in the tooltip)
            )
m

# %% [markdown]
# ## Add street view
# https://www.mkrgeo-blog.com/open-street-view-with-python-folium-map/
#
# https://elvinouyang.github.io/project/how-to-query-google-street-view-api-with-python/

# %%
test

# %%
#df = pd.read_csv("cf_geo.csv")
df = test
fc=folium.FeatureGroup(name="CF_GEO",overlay=True)
#cf_cluster = MarkerCluster(name="CF_GEO").add_to(map)
for i,row in df.iterrows():
    lat = df.at[i, 'u']  #latitude
    lng = df.at[i, 'v']  #longitude
    sp = df.at[i, 'sp']
    stat = df.at[i,'status'] 

popup = df.at[i,'sp'] +'<br>' + str(df.at[i, 'street']) + '<br>' + str(df.at[i, 'post code']) + '<br>' + '<a href="https://www.google.com/maps?layer=c&cbll=' + str(df.at[i, 'lat']) + ',' + str(df.at[i, 'lng']) + '" target="blank">GOOGLE STREET VIEW</a>'
cf_marker = folium.Marker(location=[lat,lng], popup=popup, icon = folium.Icon(color='green', icon='glyphicon-calendar'))
cf_cluster.add_child(cf_marker)

# %%
fig, ax = plt.subplots(figsize=(24, 18))
streets.plot(ax=ax, legend=True)
test.plot(ax=ax, color='red')
plt.title("Reims")
plt.show(False)
print('simple mpl')
